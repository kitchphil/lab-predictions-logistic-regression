# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import getpass  # To get the password without showing the input
import re
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
engine = create_engine(connection_string)

# %%
#SQL Query to Extract relevent columns

film =  '''
SELECT 
    t1.film_id 
    , COUNT(t3.rental_id) rented_times
    , t1.rental_duration
    , t5.name as category
    , t1.length
    , t1.rating
    , t1.special_features 
    , t1.rental_rate
    , t6.name AS language
    , CASE
    WHEN t3.rental_date BETWEEN '2005-05-01' AND '2005-05-31' THEN True
    ELSE False 
    END AS test
FROM 
    sakila.film AS t1
LEFT JOIN inventory AS t2 ON t1.film_id = t2.film_id
INNER JOIN sakila.rental AS t3 ON t2.inventory_id = t3.inventory_id
INNER JOIN sakila.film_category AS t4 ON t1.film_id = t4.film_id
INNER JOIN sakila.category AS t5 ON t4.category_id = t5.category_id
INNER JOIN sakila.language AS t6 ON t1.language_id = t6.language_id
#Where 
#    t3.rental_date Between '2005-01-01' AND '2005-12-31'
GROUP BY 
    film_id
    , t1.rental_duration
    , category
    , t1.length
    , t1.rating
    , test
    , t1.rental_rate
    , t1.special_features
    , language
; 

'''


dfr = pd.read_sql_query(film, engine)

# %%
dfr.duplicated().sum()
# Out:
# 0

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1585 entries, 0 to 1584
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1585 non-null   int64
#  1   rented_times      1585 non-null   int64
#  2   rental_duration   1585 non-null   int64
#  3   category          1585 non-null   object
#  4   length            1585 non-null   int64
#  5   rating            1585 non-null   object
#  6   special_features  1585 non-null   object
#  7   rental_rate       1585 non-null   float64
#  8   language          1585 non-null   object
#  9   test              1585 non-null   int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 124.0+ KB

# %%
dfr['test'].unique()
# Out:
# array([0, 1])

# %%
#Check the different values in special features. In order to make this useful, we will need to separate these values. 

dfr['special_features'].value_counts()
# Out:
# Trailers,Commentaries,Behind the Scenes                   132
# Deleted Scenes,Behind the Scenes                          117
# Trailers                                                  115
# Commentaries,Behind the Scenes                            110
# Behind the Scenes                                         109
# Trailers,Commentaries                                     109
# Commentaries,Deleted Scenes,Behind the Scenes             108
# Trailers,Deleted Scenes                                   106
# Commentaries                                              106
# Commentaries,Deleted Scenes                               103
# Trailers,Behind the Scenes                                103
# Deleted Scenes                                            100
# Trailers,Commentaries,Deleted Scenes                       95
# Trailers,Commentaries,Deleted Scenes,Behind the Scenes     92
# Trailers,Deleted Scenes,Behind the Scenes                  80
# Name: special_features, dtype: int64

# %%
dfr.duplicated().sum()
# Out:
# 0

# %%
#loop using Regex to extract values and insert them into a list, finally putting them into their own columns


la = []
lb = []
lc = []
ld = []

for i in dfr['special_features']:
        if re.findall('Trailers', i):
            la.append(1)
        else:
            la.append(0)
dfr['trailers'] = la

for i in dfr['special_features']:
        if re.findall('Behind the Scenes', i):
            lb.append(1)
        else:
            lb.append(0)
dfr['behind the scenes'] = lb            

            
for i in dfr['special_features']:
        if re.findall('Commentaries', i):
            lc.append(1)
        else:
            lc.append(0)
dfr['commentaries'] = lc
            
            
for i in dfr['special_features']:
        if re.findall('Deleted Scenes', i):
            ld.append(1)
        else:
            ld.append(0)
dfr['deleted scenes'] = ld

dfr = dfr.drop(['special_features'], axis=1)

# %%
dfr
# Out:
#       film_id  rented_times  rental_duration category  length rating  \
# 0         989            23                4   Travel      74      R
# 1         989             2                4   Travel      74      R
# 2         988            15                7   Travel     139      R
# 3         981            21                7   Travel      55  NC-17
# 4         977            12                3   Travel      85      R
# ...       ...           ...              ...      ...     ...    ...
# 1580       29            10                5   Action     168  NC-17
# 1581       21             2                3   Action     129      R
# 1582       21            20                3   Action     129      R
# 1583       19            20                6   Action     113     PG
# 1584       19             1                6   Action     113     PG
#
#       rental_rate language  test  trailers  behind the scenes  commentaries  \
# 0            4.99  English     0         0                  0             1
# 1            4.99  English     1         0                  0             1
# 2            2.99  English     0         1                  1             1
# 3            0.99  English     0         0                  1             0
# 4            2.99  English     0         0                  1             0
# ...           ...      ...   ...       ...                ...           ...
# 1580         2.99  English     0         1                  0             1
# 1581         4.99  English     1         0                  1             1
# 1582         4.99  English     0         0                  1             1
# 1583         0.99  English     0         0                  1             1
# 1584         0.99  English     1         0                  1             1
#
#       deleted scenes
# 0                  1
# 1                  1
# 2                  0
# 3                  0
# 4                  1
# ...              ...
# 1580               1
# 1581               0
# 1582               0
# 1583               1
# 1584               1
#
# [1585 rows x 13 columns]

# %%
#Conversion of the different datatypes

dfr['film_id'] = dfr['film_id'].astype(object)
dfr['rental_duration'] = dfr['rental_duration'].astype(object)
dfr['test'] = dfr['test'].astype(bool)
dfr['rental_rate'] = dfr['rental_rate'].astype(object)
dfr['trailers'] = dfr['trailers'].astype(bool)
dfr['behind the scenes'] = dfr['behind the scenes'].astype(bool)
dfr['commentaries'] = dfr['commentaries'].astype(bool)
dfr['deleted scenes'] = dfr['deleted scenes'].astype(bool)

# %%
#Now it's time to split the x and y to train and test.

y = dfr['test']
X = dfr.drop('test', axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1337)

# %%
#Extract numerical columns
X_train_num = X_train.select_dtypes(include = np.number)

#Normalise the columns to be between 0 and 1
transformer = MinMaxScaler().fit(X_train_num) # need to keep transformer
X_train_normalized = transformer.transform(X_train_num)
X_train_norm = pd.DataFrame(X_train_normalized)

# %%
X_train_norm.columns = X_train_num.columns
X_train_norm.head()
# Out:
#    rented_times    length
# 0      0.600000  0.762590
# 1      0.000000  1.000000
# 2      0.000000  0.604317
# 3      0.200000  0.812950
# 4      0.366667  0.726619

# %%
#Extract categorical columns
X_train_cat = X_train.select_dtypes(include = np.object)
X_train_cat
# Out:
# /var/folders/sm/8s2c1j894rq6v788yfhxt27r0000gn/T/ipykernel_45828/962131939.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_train_cat = X_train.select_dtypes(include = np.object)
#      film_id rental_duration     category rating rental_rate language
# 89       898               4       Sports  PG-13        4.99  English
# 1480     991               4       Action     PG        2.99  English
# 876        5               6       Family      G        2.99  English
# 1031     622               4  Documentary      G        0.99  English
# 675      770               5      Foreign      G        2.99  English
# ...      ...             ...          ...    ...         ...      ...
# 1191     951               6     Classics  PG-13        0.99  English
# 1256     249               7     Classics      G        0.99  English
# 860       83               5       Family      G        2.99  English
# 189      176               6       Sports  PG-13        0.99  English
# 1175     178               6       Comedy      G        0.99  English
#
# [1268 rows x 6 columns]

# %%
#Get dummies of categorical columns
X_train_categorical = X_train.select_dtypes(include = np.object)
X_train_cat = pd.get_dummies(X_train_categorical, 
                             columns=['category', 'rating','rental_duration','rental_rate','language'],
                             drop_first=True)
X_train_cat.head()
# Out:
# /var/folders/sm/8s2c1j894rq6v788yfhxt27r0000gn/T/ipykernel_45828/291361816.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_train_categorical = X_train.select_dtypes(include = np.object)
#      film_id  category_Animation  category_Children  category_Classics  \
# 89       898                   0                  0                  0
# 1480     991                   0                  0                  0
# 876        5                   0                  0                  0
# 1031     622                   0                  0                  0
# 675      770                   0                  0                  0
#
#       category_Comedy  category_Documentary  category_Drama  category_Family  \
# 89                  0                     0               0                0
# 1480                0                     0               0                0
# 876                 0                     0               0                1
# 1031                0                     1               0                0
# 675                 0                     0               0                0
#
#       category_Foreign  category_Games  ...  rating_NC-17  rating_PG  \
# 89                   0               0  ...             0          0
# 1480                 0               0  ...             0          1
# 876                  0               0  ...             0          0
# 1031                 0               0  ...             0          0
# 675                  1               0  ...             0          0
#
#       rating_PG-13  rating_R  rental_duration_4  rental_duration_5  \
# 89               1         0                  1                  0
# 1480             0         0                  1                  0
# 876              0         0                  0                  0
# 1031             0         0                  1                  0
# 675              0         0                  0                  1
#
#       rental_duration_6  rental_duration_7  rental_rate_2.99  rental_rate_4.99
# 89                    0                  0                 0                 1
# 1480                  0                  0                 1                 0
# 876                   1                  0                 1                 0
# 1031                  0                  0                 0                 0
# 675                   0                  0                 1                 0
#
# [5 rows x 26 columns]

# %%
#Concatenate the numerical and non-numerical
X_train_transformed = np.concatenate([X_train_norm, X_train_cat], axis=1)

# %%
#Run the Train Model
from sklearn.linear_model import LogisticRegression
classification = LogisticRegression(random_state=0, solver='lbfgs',
                  multi_class='multinomial').fit(X_train_transformed, y_train)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#Repeat the same process for Test

#Extract numerical columns
X_test_num = X_test.select_dtypes(include = np.number)

#Normalise the columns to be between 0 and 1
X_test_normalized = transformer.transform(X_test_num)
X_test_norm = pd.DataFrame(X_test_normalized)

# %%
#Extract categorical columns
X_test_categorical = X_test.select_dtypes(include = np.object)

#Get dummies of categorical columns
X_test_cat = pd.get_dummies(X_test_categorical, 
                            columns=['category', 'rating','rental_duration','rental_rate','language'],
                            drop_first=True)

#  Make sure the columns are in the same order as Train
display(list(zip(list(X_train_cat.columns),list(X_test_cat.columns))))
X_test_cat.head()
# Out:
# /var/folders/sm/8s2c1j894rq6v788yfhxt27r0000gn/T/ipykernel_45828/700469127.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   X_test_categorical = X_test.select_dtypes(include = np.object)
# [('film_id', 'film_id'),
#  ('category_Animation', 'category_Animation'),
#  ('category_Children', 'category_Children'),
#  ('category_Classics', 'category_Classics'),
#  ('category_Comedy', 'category_Comedy'),
#  ('category_Documentary', 'category_Documentary'),
#  ('category_Drama', 'category_Drama'),
#  ('category_Family', 'category_Family'),
#  ('category_Foreign', 'category_Foreign'),
#  ('category_Games', 'category_Games'),
#  ('category_Horror', 'category_Horror'),
#  ('category_Music', 'category_Music'),
#  ('category_New', 'category_New'),
#  ('category_Sci-Fi', 'category_Sci-Fi'),
#  ('category_Sports', 'category_Sports'),
#  ('category_Travel', 'category_Travel'),
#  ('rating_NC-17', 'rating_NC-17'),
#  ('rating_PG', 'rating_PG'),
#  ('rating_PG-13', 'rating_PG-13'),
#  ('rating_R', 'rating_R'),
#  ('rental_duration_4', 'rental_duration_4'),
#  ('rental_duration_5', 'rental_duration_5'),
#  ('rental_duration_6', 'rental_duration_6'),
#  ('rental_duration_7', 'rental_duration_7'),
#  ('rental_rate_2.99', 'rental_rate_2.99'),
#  ('rental_rate_4.99', 'rental_rate_4.99')]
#      film_id  category_Animation  category_Children  category_Classics  \
# 1315     553                   0                  1                  0
# 420      673                   0                  0                  0
# 1070     206                   0                  0                  0
# 1198     862                   0                  0                  1
# 219      831                   0                  0                  0
#
#       category_Comedy  category_Documentary  category_Drama  category_Family  \
# 1315                0                     0               0                0
# 420                 0                     0               0                0
# 1070                0                     1               0                0
# 1198                0                     0               0                0
# 219                 0                     0               0                0
#
#       category_Foreign  category_Games  ...  rating_NC-17  rating_PG  \
# 1315                 0               0  ...             0          0
# 420                  0               0  ...             0          0
# 1070                 0               0  ...             0          0
# 1198                 0               0  ...             0          0
# 219                  0               0  ...             0          0
#
#       rating_PG-13  rating_R  rental_duration_4  rental_duration_5  \
# 1315             1         0                  1                  0
# 420              1         0                  0                  0
# 1070             0         0                  0                  0
# 1198             0         0                  0                  1
# 219              1         0                  0                  1
#
#       rental_duration_6  rental_duration_7  rental_rate_2.99  rental_rate_4.99
# 1315                  0                  0                 0                 0
# 420                   0                  0                 0                 0
# 1070                  1                  0                 0                 0
# 1198                  0                  0                 0                 0
# 219                   0                  0                 0                 0
#
# [5 rows x 26 columns]

# %%
#Concatenate the numerical and non-numerical
X_test_transformed = np.concatenate([X_test_norm, X_test_cat], axis=1)

# %%
# The prediction:

predictions = classification.predict(X_test_transformed)
classification.score(X_test_transformed, y_test)
# Out:
# 0.9779179810725552

# %%
print(y_test.value_counts())
# Out:
# False    202
# True     115
# Name: test, dtype: int64

# %%
pd.Series(predictions).value_counts()
# This shows that the disparity in the numbers are amplified by the model
# Out:
# False    195
# True     122
# dtype: int64

# %%
#Use the confusion matrix to see accuracy of predictions. 
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[195,   7],
#        [  0, 115]])

# %%
# Look at nearest neighbours 
from sklearn import neighbors
clf = neighbors.KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train_transformed, y_train)
predictions_clf = clf.predict(X_test_transformed)
clf.score(X_test_transformed, y_test)
# Out:
# 0.4605678233438486
